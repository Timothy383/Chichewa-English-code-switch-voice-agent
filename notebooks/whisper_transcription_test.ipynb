# %%
# Whisper Transcription Test

'''This notebook tests speech recognition on a small Chichewa–English dataset using the Whisper model.

Goal:
- Load a pretrained Whisper model
- Transcribe a few audio samples
- Compare the predictions with expected phrases'''


import whisper

# %%
# Load Whisper model
model = whisper.load_model("small")

# %%
# Test first 3 audios
for i in range(3):

    audio = df_finetune.iloc[i]["audio_path"]
    result = model.transcribe(audio)

    print("Audio:", audio)
    print("Prediction:", result["text"])
    print("-" * 40)
